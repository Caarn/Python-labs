# %%
# Лабораторная работа № 0
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tkinter as tk
from tkinter import ttk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg


data = {
'Хлеб': np.random.normal(40, 83, 12),
'Рыба': np.random.normal(107, 4, 12),
'Пирожки': np.random.normal(40, 23, 12),
'Колбаса': np.random.normal(108, 9, 12),
'Соль': np.random.normal(49, 40, 12),
'Перец': np.random.normal(30, 49, 12),
'Макароны': np.random.normal(75, 7, 12),
'Вода': np.random.normal(49, 75, 12),
'Сахар': np.random.normal(65, 45, 12),
"Квас": np.random.normal(90, 5, 12),
}
df = pd.DataFrame(data).transpose() 
df
# Out:
#                   0           1           2           3           4   \
# Хлеб        0.393385 -194.410417   78.545744  148.880288   95.743425
# Рыба      110.773733  114.244797  110.431371  109.544122  116.336981
# Пирожки    27.755550    0.950666   37.678781   62.093071   16.572261
# Колбаса   121.464399  108.153704  107.635069  101.655664  111.181135
# Соль       10.328995   69.994793   54.784647   68.522640   55.584377
# Перец      71.989571  -12.885885   15.457795   74.417795  -23.172087
# Макароны   82.043853   79.452943   74.975647   58.490886   76.949069
# Вода      100.527836   34.000963  -90.074641   93.556303   76.914728
# Сахар     110.943891   37.847250   41.781710   88.988467   83.999685
# Квас      -58.082160  113.845719   35.577207  117.486696   40.979634
#
#                   5           6           7           8           9   \
# Хлеб      103.641905  -53.417641  -21.588163  -57.295484  -54.708685
# Рыба      107.362108  105.765542  105.358072  104.050877  113.053444
# Пирожки    14.037826   17.252917    9.843235   72.297664   81.637928
# Колбаса   116.295184  116.633916  101.652594  110.212620  106.045662
# Соль       97.252463   80.706622   38.700385   33.584135   80.215496
# Перец       0.740964   65.650932  -38.419735   54.469979  -58.255291
# Макароны   78.101818   72.793729   78.696258   64.796382   80.465433
# Вода       12.816916  156.360160  115.724519   39.487406  -98.192625
# Сахар     123.859417  -28.103121   99.223528   53.266941  117.936606
# Квас       24.637276  159.180032   88.537674  149.977801  146.087609
#
#                   10          11
# Хлеб     -114.801568  -25.164175
# Рыба      106.135333  110.450968
# Пирожки    15.055699   -0.682815
# Колбаса    95.399913   99.634680
# Соль       14.860361   33.983040
# Перец      56.424667   -2.420653
# Макароны   73.541151   73.808277
# Вода      211.639678  -62.666250
# Сахар       8.055259  156.737504
# Квас      211.076473  134.668659

# %%
ax = sns.lineplot(df)
sns.move_legend(ax, 'upper left', bbox_to_anchor=(1, 1))

# %%
p0 = df.sum() / df.shape[0] 
p0
# Out:
# 0     57.813905
# 1     35.119453
# 2     46.679333
# 3     92.363593
# 4     65.108921
# 5     67.874588
# 6     69.282309
# 7     57.772837
# 8     62.484832
# 9     51.428558
# 10    67.738697
# 11    51.834923
# dtype: float64

# %%
std = ((df - p0**2).sum() / (df.shape[0] - 1))
std = std ** (1/2) 

x_extrapol = p0 + np.random.normal(0, std, len(p0))
pd.concat([df, pd.DataFrame([x_extrapol], columns = x_extrapol.index)]).reset_index(drop = True)
# Out:
#             0           1           2           3           4           5   \
# 0     0.393385 -194.410417   78.545744  148.880288   95.743425  103.641905
# 1   110.773733  114.244797  110.431371  109.544122  116.336981  107.362108
# 2    27.755550    0.950666   37.678781   62.093071   16.572261   14.037826
# 3   121.464399  108.153704  107.635069  101.655664  111.181135  116.295184
# 4    10.328995   69.994793   54.784647   68.522640   55.584377   97.252463
# 5    71.989571  -12.885885   15.457795   74.417795  -23.172087    0.740964
# 6    82.043853   79.452943   74.975647   58.490886   76.949069   78.101818
# 7   100.527836   34.000963  -90.074641   93.556303   76.914728   12.816916
# 8   110.943891   37.847250   41.781710   88.988467   83.999685  123.859417
# 9   -58.082160  113.845719   35.577207  117.486696   40.979634   24.637276
# 10         NaN         NaN         NaN         NaN         NaN         NaN
#
#             6           7           8           9           10          11
# 0   -53.417641  -21.588163  -57.295484  -54.708685 -114.801568  -25.164175
# 1   105.765542  105.358072  104.050877  113.053444  106.135333  110.450968
# 2    17.252917    9.843235   72.297664   81.637928   15.055699   -0.682815
# 3   116.633916  101.652594  110.212620  106.045662   95.399913   99.634680
# 4    80.706622   38.700385   33.584135   80.215496   14.860361   33.983040
# 5    65.650932  -38.419735   54.469979  -58.255291   56.424667   -2.420653
# 6    72.793729   78.696258   64.796382   80.465433   73.541151   73.808277
# 7   156.360160  115.724519   39.487406  -98.192625  211.639678  -62.666250
# 8   -28.103121   99.223528   53.266941  117.936606    8.055259  156.737504
# 9   159.180032   88.537674  149.977801  146.087609  211.076473  134.668659
# 10         NaN         NaN         NaN         NaN         NaN         NaN

# %%
reliability = std/p0 
reliability
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# dtype: float64

# %%
cond1 = ((df - p0) < 2 * std).all() 
cond1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
cond2 = p0 > 2 * std 
cond2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
cond3 = (df > 0).all() 
cond3
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
product_color = pd.Series(dtype = 'string')
for name in df.columns:
    if (not cond3[name]):
        product_color[name] = 'Красный'
    elif (not cond1[name] and not cond2[name]):
        product_color[name] = 'Оранжевый'
    elif (not cond1[name] or not cond2[name]):
        product_color[name] = 'Жёлтый'
    else:
        product_color[name] = 'Зелёный'
product_color
# Out:
# 0       Красный
# 1       Красный
# 2       Красный
# 3     Оранжевый
# 4       Красный
# 5     Оранжевый
# 6       Красный
# 7       Красный
# 8       Красный
# 9       Красный
# 10      Красный
# 11      Красный
# dtype: object
